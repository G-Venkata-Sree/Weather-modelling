# %% [markdown]
# <a href="https://colab.research.google.com/github/G-Venkata-Sree/Weather-modelling/blob/main/SE_weather_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def solve_and_plot(a, b, c, title, show_plot=True):
    disc = b**2 - 4*a*c
    r1 = (-b + disc**0.5) / (2*a)
    r2 = (-b - disc**0.5) / (2*a)
    print(f"{title} Roots: {r1}, {r2}")
    x = np.linspace(-5, 5, 400)
    y = a*x**2 + b*x + c
    plt.plot(x, y, label=f"{a}x² + {b}x + {c}")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.scatter([r1, r2], [0,0], color='red', label=f"Roots ({title})")
    if show_plot:
        plt.legend(); plt.grid(True); plt.title(title); plt.show()



# Stage 4: Multiple sets in ONE graph
with open("multi_coeff.txt", "w") as f:
    f.write("1 -3 2\n2 -4 -6\n1 2 1")

print("\nMultiple Sets from File:")
plt.figure()
with open("multi_coeff.txt") as f:
    for idx, line in enumerate(f, start=1):
        a, b, c = map(float, line.split())
        solve_and_plot(a, b, c, f"Set {idx}", show_plot=False)

plt.title("Multiple Quadratic Sets in One Graph")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Multiple Sets from File:
# Set 1 Roots: 2.0, 1.0
# Set 2 Roots: 3.0, -1.0
# Set 3 Roots: -1.0, -1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

def solve_and_plot(a, b, c, title, show_plot=True):
    disc = b**2 - 4*a*c
    r1 = (-b + disc**0.5) / (2*a)
    r2 = (-b - disc**0.5) / (2*a)
    print(f"{title} Roots: {r1}, {r2}")
    x = np.linspace(-5, 5, 400)
    y = a*x**2 + b*x + c
    plt.plot(x, y, label=f"{a}x² + {b}x + {c}")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.scatter([r1, r2], [0,0], color='red', label=f"Roots ({title})")
    if show_plot:
        plt.legend(); plt.grid(True); plt.title(title); plt.show()


# Stage 2: Keyboard input simulation
plt.figure()
solve_and_plot(2, -4, -6, "Keyboard Input")
# Out:
# Keyboard Input Roots: 3.0, -1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

def solve_and_plot(a, b, c, title, show_plot=True):
    disc = b**2 - 4*a*c
    r1 = (-b + disc**0.5) / (2*a)
    r2 = (-b - disc**0.5) / (2*a)
    print(f"{title} Roots: {r1}, {r2}")
    x = np.linspace(-5, 5, 400)
    y = a*x**2 + b*x + c
    plt.plot(x, y, label=f"{a}x² + {b}x + {c}")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.scatter([r1, r2], [0,0], color='red', label=f"Roots ({title})")
    if show_plot:
        plt.legend(); plt.grid(True); plt.title(title); plt.show()

# Stage 1: Hard-coded
plt.figure()
solve_and_plot(1, -3, 2, "Hard-coded Variables")
# Out:
# Hard-coded Variables Roots: 2.0, 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

def solve_and_plot(a, b, c, title, show_plot=True):
    disc = b**2 - 4*a*c
    r1 = (-b + disc**0.5) / (2*a)
    r2 = (-b - disc**0.5) / (2*a)
    print(f"{title} Roots: {r1}, {r2}")
    x = np.linspace(-5, 5, 400)
    y = a*x**2 + b*x + c
    plt.plot(x, y, label=f"{a}x² + {b}x + {c}")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.scatter([r1, r2], [0,0], color='red', label=f"Roots ({title})")
    if show_plot:
        plt.legend(); plt.grid(True); plt.title(title); plt.show()

# Stage 3: Single set from file
with open("coeff.txt", "w") as f:
    f.write("1 2 1")
with open("coeff.txt") as f:
    a, b, c = map(float, f.readline().split())
plt.figure()
solve_and_plot(a, b, c, "Single Set from File")
# Out:
# Single Set from File Roots: -1.0, -1.0
